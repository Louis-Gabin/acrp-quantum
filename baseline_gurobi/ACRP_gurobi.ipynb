# %%
import Instance
import Optimization

# %%
filename = "/Users/louis-gabin/Library/CloudStorage/OneDrive-SKEMABusinessSchool/SKEMA/MASTER 2/S6/THESIS LOUIS/acrp-quantum 2/baseline_gurobi/CP_4.dat"
#filename = 'RCP_10_1.dat'
ins = Instance.Instance(filename,"static")
ins.preprocessing()

# %%
opt = Optimization.Optimization(ins)
opt.solveMINLP()
# Out:
# Set parameter NonConvex to value 2
# OFV: 3
# 1	0	1.000	0.000
# 2	1	0.992	-0.332
# 3	1	0.984	-0.322
# 4	1	0.978	-0.313
